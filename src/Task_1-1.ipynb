# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr
from sklearn.model_selection import KFold
import time
from tqdm import tqdm
from multiprocessing import Pool, cpu_count
from multiprocessing.managers import SyncManager as Manager
from functools import partial
import warnings
warnings.filterwarnings('ignore')

class ProgressTracker:
    def __init__(self, total, desc):
        self.pbar = tqdm(total=total, desc=desc, position=0)
    
    def update(self):
        self.pbar.update(1)
    
    def close(self):
        self.pbar.close()
        
class MovieRecommender:
    def __init__(self):
        self.users_df = None
        self.movies_df = None
        self.ratings_df = None
        self.user_movie_matrix = None
        
    def load_data(self):
        """
        Load the MovieLens 1M dataset
        """
        print("\n=== Loading MovieLens 1M Dataset ===")
        
        print("Loading ratings data...")
        self.ratings_df = pd.read_csv('ratings.dat', 
                                    sep='::', 
                                    names=['UserID', 'MovieID', 'Rating', 'Timestamp'],
                                    engine='python')
        print(f"✓ Loaded {len(self.ratings_df)} ratings")
        
        print("Loading movies data...")
        self.movies_df = pd.read_csv('movies.dat',
                                   sep='::',
                                   names=['MovieID', 'Title', 'Genres'],
                                   engine='python',
                                   encoding='ISO-8859-1')
        print(f"✓ Loaded {len(self.movies_df)} movies")
        
        print("Loading users data...")
        self.users_df = pd.read_csv('users.dat',
                                  sep='::',
                                  names=['UserID', 'Gender', 'Age', 'Occupation', 'Zip-code'],
                                  engine='python')
        print(f"✓ Loaded {len(self.users_df)} users")
        
        print("Creating user-movie rating matrix...")
        self.user_movie_matrix = self.ratings_df.pivot(
            index='UserID',
            columns='MovieID',
            values='Rating'
        ).fillna(0)
        print(f"✓ Created matrix with shape: {self.user_movie_matrix.shape}")
        
        return self.ratings_df, self.movies_df, self.users_df
    
    def calculate_similarity(self, user_id, similarity_metric='cosine'):
        """Calculate similarity between target user and all other users"""
        user_vector = self.user_movie_matrix.loc[user_id].values.reshape(1, -1)
        other_users = self.user_movie_matrix.values
        
        if similarity_metric == 'cosine':
            return cosine_similarity(user_vector, other_users)[0]
        elif similarity_metric == 'pearson':
            return np.array([pearsonr(user_vector[0], other_user)[0] 
                           for other_user in other_users])
    
    def predict_ratings(self, user_id, k=5, similarity_metric='cosine'):
        """Predict ratings for all movies for a given user using kNN"""
        similarities = self.calculate_similarity(user_id, similarity_metric)
        user_index = self.user_movie_matrix.index.get_loc(user_id)
        similarities[user_index] = -np.inf
        neighbor_indices = np.argsort(similarities)[-k:]
        
        neighbor_ratings = self.user_movie_matrix.iloc[neighbor_indices]
        weights = similarities[neighbor_indices].reshape(-1, 1)
        weighted_ratings = neighbor_ratings * weights
        predicted_ratings = weighted_ratings.sum(axis=0) / np.abs(weights).sum()
        
        return predicted_ratings

    def evaluate_rmse(self, test_user_id, k=5, similarity_metric='cosine'):
        """Calculate RMSE for a test user"""
        actual_ratings = self.user_movie_matrix.loc[test_user_id]
        predicted_ratings = self.predict_ratings(test_user_id, k, similarity_metric)
        
        rated_movies = actual_ratings > 0
        rmse = np.sqrt(mean_squared_error(
            actual_ratings[rated_movies],
            predicted_ratings[rated_movies]
        ))
        
        return rmse

def evaluate_users_parallel(args):
    """Helper function for parallel processing of user evaluation"""
    test_users, recommender, k, similarity_metric = args
    rmse_values = []
    
    # Calculate RMSE for each user
    for user_id in test_users:
        rmse = recommender.evaluate_rmse(user_id, k, similarity_metric)
        rmse_values.append(rmse)
            
    return np.mean(rmse_values)

class ParallelMovieRecommender(MovieRecommender):
    def find_optimal_k(self, k_values=None, n_folds=5, similarity_metric='cosine', n_jobs=None):
        """
        Find optimal k using parallel k-fold cross-validation with progress bars
        """
        print(f"\n=== Finding Optimal k using {n_folds}-fold Cross-validation (Parallel) ===")
        print(f"Similarity metric: {similarity_metric}")
        
        if k_values is None:
            k_values = [5, 10, 20, 30, 40, 50, 75, 100]
        
        if n_jobs is None:
            n_jobs = cpu_count()
            
        print(f"Testing k values: {k_values}")
        print(f"Using {n_jobs} parallel processes")
        
        # Initialize KFold
        kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
        user_ids = self.user_movie_matrix.index.values
        
        results = []
        # Create progress bars for k values
        k_pbar = tqdm(k_values, desc="Overall Progress", position=0)
        
        with Pool(processes=n_jobs) as pool:
            for k in k_pbar:
                start_time = time.time()
                k_pbar.set_description(f"Evaluating k={k}")
                fold_rmses = []
                
                # Create progress bar for folds
                fold_pbar = tqdm(total=n_folds, desc="Folds Progress", position=1, leave=False)
                
                for fold, (train_idx, test_idx) in enumerate(kf.split(user_ids), 1):
                    test_users = user_ids[test_idx]
                    
                    # Split test users into chunks
                    n_chunks = n_jobs
                    chunk_size = max(1, len(test_users) // n_chunks)
                    user_chunks = [test_users[i:i + chunk_size] for i in range(0, len(test_users), chunk_size)]
                    
                    # Create progress bar for users
                    user_pbar = tqdm(total=len(user_chunks), 
                                   desc="Users Progress", 
                                   position=2, 
                                   leave=False)
                    
                    # Prepare arguments for parallel processing
                    chunk_args = [
                        (chunk, self, k, similarity_metric)
                        for chunk in user_chunks
                    ]
                    
                    # Process chunks in parallel with progress tracking
                    chunk_rmses = []
                    for chunk_arg in chunk_args:
                        result = evaluate_users_parallel(chunk_arg)
                        chunk_rmses.append(result)
                        user_pbar.update(1)
                    
                    fold_rmse = np.mean(chunk_rmses)
                    fold_rmses.append(fold_rmse)
                    
                    # Update progress bars
                    fold_pbar.update(1)
                    user_pbar.close()
                
                avg_rmse = np.mean(fold_rmses)
                std_rmse = np.std(fold_rmses)
                
                elapsed_time = time.time() - start_time
                fold_pbar.close()
                
                # Update progress bar description with results
                k_pbar.set_postfix({
                    'RMSE': f'{avg_rmse:.4f}±{std_rmse:.4f}',
                    'Time': f'{elapsed_time:.2f}s'
                })
                
                results.append({
                    'k': k,
                    'avg_rmse': avg_rmse,
                    'std_rmse': std_rmse
                })
        
        return pd.DataFrame(results)

def evaluate_knn_parameters_parallel(n_jobs=None):
    """
    Evaluate different k values and similarity metrics in parallel with progress tracking
    """
    print("\n====================================")
    print("Starting Parallel KNN Parameter Evaluation")
    print("====================================")
    
    recommender = ParallelMovieRecommender()
    recommender.load_data()
    
    k_values = [5, 10, 20, 30, 40, 50, 75, 100]
    metrics = ['cosine', 'pearson']
    
    # Create progress bar for metrics
    metric_pbar = tqdm(metrics, desc="Metrics Progress", position=0)
    results = []
    
    for metric in metric_pbar:
        metric_pbar.set_description(f"Evaluating {metric} similarity")
        metric_results = recommender.find_optimal_k(
            k_values=k_values,
            n_folds=5,
            similarity_metric=metric,
            n_jobs=n_jobs
        )
        metric_results['metric'] = metric
        results.append(metric_results)
    
    return pd.concat(results, ignore_index=True)

if __name__ == "__main__":
    print("\nParallel Movie Recommendation System - Parameter Optimization")
    print("=" * 60)
    
    # Use 80% of available CPU cores by default
    n_jobs = max(1, int(cpu_count() * 0.8))
    print(f"\nUsing {n_jobs} parallel processes")
    
    start_time = time.time()
    
    # Create overall progress tracker
    with tqdm(total=1, desc="Overall Progress", position=0) as pbar:
        results = evaluate_knn_parameters_parallel(n_jobs=n_jobs)
        pbar.update(1)
    
    print("\n=== Final Results ===")
    print("\nDetailed Results:")
    print(results.to_string(index=False))
    
    # Find best parameters
    best_result = results.loc[results['avg_rmse'].idxmin()]
    print("\nBest Configuration Found:")
    print("-" * 30)
    print(f"k: {best_result['k']}")
    print(f"Similarity metric: {best_result['metric']}")
    print(f"RMSE: {best_result['avg_rmse']:.4f} ± {best_result['std_rmse']:.4f}")
    
    total_time = time.time() - start_time
    print(f"\nTotal execution time: {format_time(total_time)}")
# Out:
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Parallel Movie Recommendation System - Parameter Optimization
# ============================================================
#
# Using 6 parallel processes
# Overall Progress:   0%|                                                                          | 0/1 [00:00<?, ?it/s]
# ====================================
# Starting Parallel KNN Parameter Evaluation
# ====================================
#
# === Loading MovieLens 1M Dataset ===
# Loading ratings data...
# ✓ Loaded 1000209 ratings
# Loading movies data...
# ✓ Loaded 3883 movies
# Loading users data...
# ✓ Loaded 6040 users
# Creating user-movie rating matrix...
# ✓ Created matrix with shape: (6040, 3706)
# Evaluating cosine similarity:   0%|                                                              | 0/2 [00:00<?, ?it/s]
# === Finding Optimal k using 5-fold Cross-validation (Parallel) ===
# Similarity metric: cosine
# Testing k values: [5, 10, 20, 30, 40, 50, 75, 100]
# Using 6 parallel processes
# Evaluating k=5:   0%|                                                                            | 0/8 [00:00<?, ?it/s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:56, 39.49s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:15, 39.12s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:35, 38.88s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:35<01:56, 38.87s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:14<01:17, 38.93s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:54<00:39, 39.11s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:54<00:00, 26.45s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [03:54<15:38, 234.71s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:59, 39.98s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:19<03:18, 39.69s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:58<02:38, 39.52s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:58, 39.39s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:17<01:18, 39.30s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:56<00:39, 39.27s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.56s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [07:51<11:47, 235.89s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:55, 39.27s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:16, 39.36s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:57<02:37, 39.33s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:58, 39.38s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:16<01:18, 39.27s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:56<00:39, 39.37s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.63s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [11:47<07:52, 236.17s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:56, 39.47s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:16, 39.38s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:58<02:37, 39.40s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:57, 39.26s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:16<01:18, 39.13s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:55<00:39, 39.06s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:55<00:00, 26.41s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [15:43<03:55, 235.90s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:52, 38.69s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:12, 38.53s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:55<02:33, 38.48s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:34<01:55, 38.63s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:14<01:18, 39.16s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:54<00:39, 39.43s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:54<00:00, 26.67s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [19:38<00:00, 235.52s/it]
#
#
# Evaluating k=10:  12%|███▌                        | 1/8 [19:38<2:17:28, 1178.39s/it, RMSE=2.3333±0.0209, Time=1178.28s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:40<04:00, 40.10s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:20<03:20, 40.06s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:00<02:40, 40.05s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:40<01:59, 39.97s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:18<01:18, 39.29s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:56<00:38, 38.95s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.35s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [03:56<15:47, 236.80s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:50, 38.41s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:16<03:11, 38.33s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:54<02:32, 38.22s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:32<01:54, 38.19s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:11<01:16, 38.29s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:49<00:38, 38.31s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:50<00:00, 25.91s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [07:46<11:38, 232.87s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:54, 39.15s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:14, 38.95s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:34, 38.67s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:34<01:55, 38.44s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:12<01:16, 38.29s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:50<00:38, 38.24s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:50<00:00, 25.87s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [11:37<07:43, 231.99s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:49, 38.23s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:16<03:12, 38.45s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:55<02:33, 38.46s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:33<01:55, 38.54s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:12<01:16, 38.49s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:50<00:38, 38.51s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:51<00:00, 26.05s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [15:29<03:51, 231.73s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:52, 38.76s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:13, 38.71s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:34, 38.69s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:34<01:56, 38.67s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:13<01:17, 38.66s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:51<00:38, 38.64s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:52<00:00, 26.14s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [19:21<00:00, 231.98s/it]
#
#
# Evaluating k=20:  25%|███████                     | 2/8 [39:00<1:56:51, 1168.54s/it, RMSE=2.2805±0.0226, Time=1161.63s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:52, 38.79s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:14, 38.94s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:35, 38.99s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:35<01:56, 38.84s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:14<01:17, 38.77s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:53<00:38, 38.82s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:53<00:00, 26.26s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [03:53<15:33, 233.45s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:53, 38.88s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:14, 38.80s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:34, 38.73s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:35<01:56, 38.79s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:13<01:17, 38.76s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:52<00:38, 38.83s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:53<00:00, 26.26s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [07:46<11:39, 233.31s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:53, 38.94s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:14, 38.91s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:35, 38.93s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:36<01:57, 39.11s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:15<01:18, 39.01s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:53<00:38, 38.90s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:54<00:00, 26.31s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [11:40<07:47, 233.67s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:53, 38.89s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:13, 38.70s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:35, 38.88s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:35<01:56, 38.73s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:13<01:17, 38.69s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:52<00:38, 38.77s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:52<00:00, 26.22s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [15:33<03:53, 233.40s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:49, 38.25s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:16<03:12, 38.43s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:55<02:34, 38.57s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:33<01:55, 38.51s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:13<01:17, 38.79s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:51<00:38, 38.67s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:52<00:00, 26.15s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [19:25<00:00, 232.93s/it]
#
#
# Evaluating k=30:  38%|██████████▌                 | 3/8 [58:25<1:37:16, 1167.31s/it, RMSE=2.2735±0.0245, Time=1165.85s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:53, 38.89s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:16, 39.30s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:57<02:36, 39.20s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:36<01:57, 39.09s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:15<01:17, 38.93s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:53<00:38, 38.87s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:54<00:00, 26.29s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [03:54<15:37, 234.27s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:55, 39.17s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:15, 39.03s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:57<02:37, 39.25s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:36<01:57, 39.16s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:15<01:18, 39.08s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:54<00:39, 39.12s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:55<00:00, 26.46s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [07:49<11:44, 234.80s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:53, 38.92s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:15, 39.16s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:57<02:36, 39.19s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:36<01:57, 39.14s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:15<01:17, 38.94s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:53<00:38, 38.88s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:54<00:00, 26.29s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [11:43<07:49, 234.56s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:50, 38.50s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:13, 38.78s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:35, 38.79s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:35<01:56, 38.81s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:14<01:17, 38.88s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:53<00:38, 38.96s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:53<00:00, 26.35s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [15:37<03:54, 234.21s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:52, 38.76s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:13, 38.79s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:35, 38.83s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:35<01:56, 38.92s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:14<01:17, 38.99s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:53<00:38, 38.96s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:53<00:00, 26.34s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [19:31<00:00, 234.10s/it]
#
#
# Evaluating k=40:  50%|█████████████             | 4/8 [1:17:57<1:17:55, 1168.89s/it, RMSE=2.2777±0.0231, Time=1171.30s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:54, 39.03s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:14, 39.00s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:57<02:36, 39.14s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:36<01:57, 39.29s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:16<01:18, 39.45s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:56<00:39, 39.73s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:57<00:00, 26.87s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [03:57<15:48, 237.25s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:58, 39.73s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:17, 39.44s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:58<02:37, 39.37s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:57, 39.30s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:16<01:18, 39.26s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:55<00:39, 39.19s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.51s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [07:53<11:49, 236.57s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:55, 39.27s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:15, 39.07s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:35, 38.95s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:59, 39.70s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:17<01:19, 39.67s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:56<00:39, 39.47s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.69s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [11:50<07:53, 236.75s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:38<03:52, 38.79s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:17<03:14, 38.95s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:56<02:35, 38.99s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:36<01:57, 39.10s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:15<01:18, 39.13s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:54<00:39, 39.04s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:54<00:00, 26.41s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [15:44<03:55, 235.91s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:54, 39.08s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:16, 39.23s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:58<02:37, 39.43s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:58, 39.38s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:16<01:18, 39.31s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:56<00:39, 39.41s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.66s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [19:41<00:00, 236.16s/it]
#
#
# Evaluating k=50:  62%|█████████████████▌          | 5/8 [1:37:38<58:40, 1173.45s/it, RMSE=2.2849±0.0222, Time=1181.54s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:56, 39.33s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:17, 39.48s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:58<02:38, 39.52s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:58, 39.49s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:17<01:19, 39.57s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:56<00:39, 39.50s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:57<00:00, 26.71s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [03:57<15:49, 237.40s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:56, 39.50s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:17, 39.47s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:58<02:37, 39.37s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:57, 39.33s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:16<01:18, 39.33s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:56<00:39, 39.31s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.59s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [07:53<11:50, 236.87s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:55, 39.27s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:15, 39.12s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:57<02:36, 39.01s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:36<01:57, 39.13s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:15<01:18, 39.22s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:55<00:39, 39.34s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:55<00:00, 26.61s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [11:49<07:52, 236.40s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:59, 39.95s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:19<03:17, 39.43s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:58<02:37, 39.42s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:58, 39.46s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:16<01:18, 39.29s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:55<00:39, 39.18s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.50s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [15:46<03:56, 236.37s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:56, 39.37s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:16, 39.21s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:57<02:36, 39.19s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:58, 39.34s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:16<01:18, 39.38s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:55<00:39, 39.36s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:56<00:00, 26.62s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [19:42<00:00, 236.38s/it]
#
#
# Evaluating k=75:  75%|█████████████████████       | 6/8 [1:57:21<39:13, 1176.52s/it, RMSE=2.2912±0.0213, Time=1182.46s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:56, 39.35s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:18<03:16, 39.37s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:58<02:37, 39.39s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:37<01:58, 39.49s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:17<01:19, 39.62s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [03:57<00:39, 39.72s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [03:57<00:00, 26.86s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [03:57<15:51, 237.94s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:59, 39.93s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:20<03:20, 40.13s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:01<02:42, 40.54s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:41<02:01, 40.53s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:23<01:21, 40.99s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [04:04<00:41, 41.03s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [04:05<00:00, 27.76s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [08:03<12:06, 242.16s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:41<04:08, 41.48s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:21<03:24, 40.86s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:01<02:41, 40.46s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:42<02:01, 40.34s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:22<01:20, 40.31s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [04:02<00:40, 40.29s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [04:02<00:00, 27.25s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [12:06<08:05, 242.53s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:39<03:57, 39.62s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:19<03:19, 39.92s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [01:59<02:39, 39.90s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:40<02:00, 40.16s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:20<01:20, 40.18s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [04:00<00:40, 40.30s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [04:01<00:00, 27.27s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [16:07<04:02, 242.08s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:40<04:00, 40.14s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:20<03:20, 40.13s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:00<02:40, 40.22s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:41<02:00, 40.32s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:21<01:20, 40.30s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [04:02<00:40, 40.47s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [04:02<00:00, 27.37s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [20:09<00:00, 242.25s/it]
#
#
# Evaluating k=100:  88%|███████████████████████▋   | 7/8 [2:17:31<19:47, 1187.46s/it, RMSE=2.3022±0.0201, Time=1209.98s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:40<04:04, 40.78s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:21<03:23, 40.80s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:02<02:43, 40.84s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:43<02:02, 40.96s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:24<01:22, 41.07s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [04:06<00:41, 41.10s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [04:06<00:00, 27.80s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [04:06<16:25, 246.46s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:40<04:05, 40.96s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:21<03:24, 40.98s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:02<02:43, 40.89s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [02:43<02:02, 40.93s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [03:24<01:21, 40.98s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [04:05<00:40, 40.93s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [04:06<00:00, 27.69s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [08:12<12:18, 246.24s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# ...
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [04:02<03:01, 60.61s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [05:03<02:01, 60.50s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:05<01:01, 61.03s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:05<00:00, 41.27s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [24:13<06:04, 364.56s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [01:00<06:05, 60.92s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [02:02<05:06, 61.27s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [03:03<04:03, 60.97s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [04:04<03:03, 61.22s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [05:05<02:01, 60.95s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:05<01:00, 60.65s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:05<00:00, 41.05s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [30:19<00:00, 365.05s/it]
#
#
# Evaluating k=75:  75%|███████████████████▌      | 6/8 [3:04:26<1:00:58, 1829.22s/it, RMSE=2.4016±0.0141, Time=1819.56s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:59<05:54, 59.12s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:59<04:59, 59.88s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:59<03:59, 59.77s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [03:58<02:59, 59.74s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [04:59<02:00, 60.14s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:00<01:00, 60.35s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:01<00:00, 40.81s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [06:01<24:04, 361.06s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [01:00<06:04, 60.74s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [02:01<05:02, 60.53s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [03:01<04:01, 60.44s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [04:02<03:01, 60.54s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [05:02<02:00, 60.30s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:01<01:00, 60.16s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:02<00:00, 40.69s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [12:03<18:05, 361.93s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:59<05:57, 59.58s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:59<04:58, 59.67s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:58<03:58, 59.61s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [03:58<02:58, 59.48s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [04:57<01:58, 59.41s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [05:57<00:59, 59.60s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [05:57<00:00, 40.31s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [18:01<12:00, 360.13s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [01:00<06:00, 60.13s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:59<04:58, 59.69s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:59<03:59, 59.85s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [03:59<02:59, 59.95s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [04:58<01:59, 59.57s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [05:57<00:59, 59.44s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [05:58<00:00, 40.20s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [23:59<05:59, 359.43s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:59<05:54, 59.11s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:58<04:56, 59.35s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [02:58<03:58, 59.72s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [03:58<02:59, 59.86s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [04:59<02:00, 60.01s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [05:59<01:00, 60.05s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [05:59<00:00, 40.62s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [29:59<00:00, 359.60s/it]
#
#
# Evaluating k=100:  88%|███████████████████████▋   | 7/8 [3:34:26<30:19, 1819.62s/it, RMSE=2.4142±0.0126, Time=1799.87s]
# Folds Progress:   0%|                                                                            | 0/5 [00:00<?, ?it/s]
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [01:00<06:04, 60.67s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [02:02<05:07, 61.59s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [03:03<04:05, 61.36s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [04:05<03:03, 61.31s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [05:05<02:01, 60.88s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:06<01:00, 60.97s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:07<00:00, 41.25s/it]
# Folds Progress:  20%|█████████████▍                                                     | 1/5 [06:07<24:28, 367.15s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [00:59<05:58, 59.79s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [01:59<04:58, 59.80s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [03:01<04:02, 60.57s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [04:01<03:01, 60.38s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [05:01<02:00, 60.40s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:02<01:00, 60.48s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:02<00:00, 40.90s/it]
# Folds Progress:  40%|██████████████████████████▊                                        | 2/5 [12:10<18:13, 364.62s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [01:00<06:03, 60.64s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [02:02<05:06, 61.25s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [03:03<04:05, 61.36s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [04:04<03:03, 61.26s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [05:06<02:02, 61.28s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:07<01:01, 61.33s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:08<00:00, 41.48s/it]
# Folds Progress:  60%|████████████████████████████████████████▏                          | 3/5 [18:18<12:12, 366.30s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [01:00<06:05, 60.87s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [02:03<05:08, 61.64s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [03:04<04:06, 61.60s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [04:06<03:04, 61.56s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [05:08<02:03, 61.98s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:11<01:02, 62.25s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:12<00:00, 42.11s/it]
# Folds Progress:  80%|█████████████████████████████████████████████████████▌             | 4/5 [24:30<06:08, 368.64s/it]
#
#
#
# Users Progress:   0%|                                                                            | 0/7 [00:00<?, ?it/s]
#
# Users Progress:  14%|█████████▋                                                          | 1/7 [01:02<06:12, 62.13s/it]
#
# Users Progress:  29%|███████████████████▍                                                | 2/7 [02:03<05:09, 61.82s/it]
#
# Users Progress:  43%|█████████████████████████████▏                                      | 3/7 [03:06<04:09, 62.29s/it]
#
# Users Progress:  57%|██████████████████████████████████████▊                             | 4/7 [04:12<03:10, 63.55s/it]
#
# Users Progress:  71%|████████████████████████████████████████████████▌                   | 5/7 [05:14<02:06, 63.01s/it]
#
# Users Progress:  86%|██████████████████████████████████████████████████████████▎         | 6/7 [06:16<01:02, 62.88s/it]
#
# Users Progress: 100%|████████████████████████████████████████████████████████████████████| 7/7 [06:17<00:00, 42.53s/it]
# Folds Progress: 100%|███████████████████████████████████████████████████████████████████| 5/5 [30:47<00:00, 371.80s/it]
#
#
# Evaluating k=100: 100%|███████████████████████████| 8/8 [4:05:13<00:00, 1839.25s/it, RMSE=2.4263±0.0108, Time=1847.95s]
# Evaluating pearson similarity: 100%|████████████████████████████████████████████████| 2/2 [6:43:13<00:00, 12096.95s/it]
# Overall Progress: 100%|█████████████████████████████████████████████████████████████| 1/1 [6:43:18<00:00, 24198.97s/it]
# === Final Results ===
#
# Detailed Results:
#   k  avg_rmse  std_rmse  metric
#   5  2.333323  0.020899  cosine
#  10  2.280480  0.022589  cosine
#  20  2.273451  0.024451  cosine
#  30  2.277733  0.023065  cosine
#  40  2.284900  0.022154  cosine
#  50  2.291184  0.021338  cosine
#  75  2.302243  0.020110  cosine
# 100  2.311641  0.018711  cosine
#   5  2.423173  0.012596 pearson
#  10  2.385874  0.014499 pearson
#  20  2.385730  0.016490 pearson
#  30  2.390709  0.017191 pearson
#  40  2.394509  0.013667 pearson
#  50  2.401580  0.014129 pearson
#  75  2.414216  0.012635 pearson
# 100  2.426296  0.010834 pearson
#
# Best Configuration Found:
# ------------------------------
# k: 20
# Similarity metric: cosine
# RMSE: 2.2735 ± 0.0245
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\3\ipykernel_13024\3785132048.py in <module>
#     265
#     266     total_time = time.time() - start_time
# --> 267     print(f"\nTotal execution time: {format_time(total_time)}")
#
# NameError: name 'format_time' is not defined

# %%
import matplotlib
  # Use non-interactive backend
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# First, try to fix the environment
import matplotlib
matplotlib.rcParams['backend'] = 'Agg'

# Create DataFrame from your results
data = {
    'k': [5, 10, 20, 30, 40, 50, 75, 100, 5, 10, 20, 30, 40, 50, 75, 100],
    'avg_rmse': [2.333323, 2.280480, 2.273451, 2.277733, 2.284900, 2.291184, 2.302243, 2.311641,
                 2.423173, 2.385874, 2.385730, 2.390709, 2.394509, 2.401580, 2.414216, 2.426296],
    'std_rmse': [0.020899, 0.022589, 0.024451, 0.023065, 0.022154, 0.021338, 0.020110, 0.018711,
                 0.012596, 0.014499, 0.016490, 0.017191, 0.013667, 0.014129, 0.012635, 0.010834],
    'metric': ['cosine']*8 + ['pearson']*8
}

results_df = pd.DataFrame(data)

def save_all_plots():
    # Set style
    sns.set_style("whitegrid")
    colors = ['#2E86C1', '#E74C3C', '#2ECC71', '#F39C12']

    # 1. Line Plot with Error Bands
    plt.figure(figsize=(12, 6))
    for i, metric in enumerate(['cosine', 'pearson']):
        metric_data = results_df[results_df['metric'] == metric]
        plt.plot(metric_data['k'], metric_data['avg_rmse'], 
                marker='o', linewidth=2, label=f'{metric.capitalize()} Similarity',
                color=colors[i])
        
        plt.fill_between(metric_data['k'],
                        metric_data['avg_rmse'] - metric_data['std_rmse'],
                        metric_data['avg_rmse'] + metric_data['std_rmse'],
                        alpha=0.2, color=colors[i])

    plt.title('RMSE vs k for Different Similarity Metrics', fontsize=14, pad=20)
    plt.xlabel('Number of Neighbors (k)', fontsize=12)
    plt.ylabel('RMSE', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('knn_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()

    # 2. Heatmap
    plt.figure(figsize=(12, 4))
    pivot_data = results_df.pivot(index='metric', columns='k', values='avg_rmse')
    sns.heatmap(pivot_data, annot=True, fmt='.3f', cmap='YlOrRd_r',
               cbar_kws={'label': 'RMSE'})
    plt.title('RMSE Heatmap: Performance Across k Values and Metrics', 
             fontsize=14, pad=20)
    plt.xlabel('Number of Neighbors (k)', fontsize=12)
    plt.ylabel('Similarity Metric', fontsize=12)
    plt.tight_layout()
    plt.savefig('knn_heatmap.png', dpi=300, bbox_inches='tight')
    plt.close()

    # 3. Stability Analysis
    plt.figure(figsize=(12, 6))
    for i, metric in enumerate(['cosine', 'pearson']):
        metric_data = results_df[results_df['metric'] == metric]
        plt.plot(metric_data['k'], metric_data['std_rmse'], 
                marker='s', linewidth=2, label=f'{metric.capitalize()} Similarity',
                color=colors[i])

    plt.title('Model Stability Analysis: Standard Deviation Across k Values', 
             fontsize=14, pad=20)
    plt.xlabel('Number of Neighbors (k)', fontsize=12)
    plt.ylabel('Standard Deviation of RMSE', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('knn_stability.png', dpi=300, bbox_inches='tight')
    plt.close()

    # 4. Improvement Plot
    plt.figure(figsize=(12, 6))
    for i, metric in enumerate(['cosine', 'pearson']):
        metric_data = results_df[results_df['metric'] == metric]
        baseline_rmse = metric_data['avg_rmse'].max()
        improvement = ((baseline_rmse - metric_data['avg_rmse']) / baseline_rmse) * 100
        
        plt.plot(metric_data['k'], improvement, 
                marker='D', linewidth=2, label=f'{metric.capitalize()} Similarity',
                color=colors[i])

    plt.title('Performance Improvement Over Baseline', 
             fontsize=14, pad=20)
    plt.xlabel('Number of Neighbors (k)', fontsize=12)
    plt.ylabel('Improvement (%)', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('knn_improvement.png', dpi=300, bbox_inches='tight')
    plt.close()

    # Create and save summary statistics
    summary_stats = pd.DataFrame({
        'Metric': ['Cosine', 'Pearson'],
        'Best RMSE': [
            f"{results_df[results_df['metric'] == 'cosine']['avg_rmse'].min():.4f}",
            f"{results_df[results_df['metric'] == 'pearson']['avg_rmse'].min():.4f}"
        ],
        'Optimal k': [
            results_df[results_df['metric'] == 'cosine']['avg_rmse'].idxmin(),
            results_df[results_df['metric'] == 'pearson']['avg_rmse'].idxmin()
        ],
        'Std Dev': [
            f"{results_df[results_df['metric'] == 'cosine']['std_rmse'].mean():.4f}",
            f"{results_df[results_df['metric'] == 'pearson']['std_rmse'].mean():.4f}"
        ]
    })
    
    summary_stats.to_csv('knn_summary_stats.csv', index=False)

    # Print analysis
    print("\nKNN Analysis Results")
    print("=" * 50)
    print("\nBest Overall Configuration:")
    best_idx = results_df['avg_rmse'].idxmin()
    print(f"• Similarity Metric: {results_df.loc[best_idx, 'metric']}")
    print(f"• k Value: {results_df.loc[best_idx, 'k']}")
    print(f"• RMSE: {results_df.loc[best_idx, 'avg_rmse']:.4f} ± {results_df.loc[best_idx, 'std_rmse']:.4f}")

    print("\nPerformance by Metric:")
    for metric in ['cosine', 'pearson']:
        metric_data = results_df[results_df['metric'] == metric]
        print(f"\n{metric.capitalize()} Similarity:")
        print(f"• Best k: {metric_data.loc[metric_data['avg_rmse'].idxmin(), 'k']}")
        print(f"• RMSE Range: {metric_data['avg_rmse'].min():.4f} - {metric_data['avg_rmse'].max():.4f}")
        print(f"• Average Stability (std): {metric_data['std_rmse'].mean():.4f}")

    print("\nFiles saved:")
    print("• knn_comparison.png - RMSE vs k comparison")
    print("• knn_heatmap.png - Performance heatmap")
    print("• knn_stability.png - Stability analysis")
    print("• knn_improvement.png - Improvement over baseline")
    print("• knn_summary_stats.csv - Summary statistics")

# Run the analysis and save all plots
save_all_plots()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\3\ipykernel_13024\1552855887.py in <module>
#     145
#     146 # Run the analysis and save all plots
# --> 147 save_all_plots()
#
# ~\AppData\Local\Temp\3\ipykernel_13024\1552855887.py in save_all_plots()
#      46     plt.grid(True, alpha=0.3)
#      47     plt.tight_layout()
# ---> 48     plt.savefig('knn_comparison.png', dpi=300, bbox_inches='tight')
#      49     plt.close()
#      50
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721
#     722     figsize : (float, float), default: :rc:`figure.figsize`
# --> 723         Width, height in inches.
#     724
#     725     dpi : float, default: :rc:`figure.dpi`
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             The figure patch face color.
#    2202
# -> 2203         edgecolor : default: :rc:`figure.edgecolor`
#    2204             The figure patch edge color.
#    2205
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2089         By default, this is 1, meaning physical and logical pixels are the same
#    2090         size. Subclasses that support High DPI screens may set this property to
# -> 2091         indicate that said ratio is different. All Matplotlib interaction,
#    2092         unless working directly with the canvas, remains in logical pixels.
#    2093
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\backend_bases.py in _get_renderer(figure, print_method)
#    1558         event.key = event.canvas._key
#    1559     # Emit axes_enter/axes_leave.
# -> 1560     if event.name == "motion_notify_event":
#    1561         last = LocationEvent.lastevent
#    1562         last_axes = last.inaxes if last is not None else None
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     503         pil_kwargs : dict, optional
#     504             Keyword arguments passed to `PIL.Image.Image.save`.
# --> 505
#     506             If the 'pnginfo' key is present, it completely overrides
#     507             *metadata*, including the default 'Software' key.
#
# ImportError: cannot import name '_png' from 'matplotlib' (C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\__init__.py)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2089         By default, this is 1, meaning physical and logical pixels are the same
#    2090         size. Subclasses that support High DPI screens may set this property to
# -> 2091         indicate that said ratio is different. All Matplotlib interaction,
#    2092         unless working directly with the canvas, remains in logical pixels.
#    2093
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\backend_bases.py in _get_renderer(figure, print_method)
#    1558         event.key = event.canvas._key
#    1559     # Emit axes_enter/axes_leave.
# -> 1560     if event.name == "motion_notify_event":
#    1561         last = LocationEvent.lastevent
#    1562         last_axes = last.inaxes if last is not None else None
#
# C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     503         pil_kwargs : dict, optional
#     504             Keyword arguments passed to `PIL.Image.Image.save`.
# --> 505
#     506             If the 'pnginfo' key is present, it completely overrides
#     507             *metadata*, including the default 'Software' key.
#
# ImportError: cannot import name '_png' from 'matplotlib' (C:\ProgramData\Anaconda3\envs\ct-env\lib\site-packages\matplotlib\__init__.py)

# %%
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (3.7.5)
# Requirement already satisfied: numpy<2,>=1.20 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\ct-env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
